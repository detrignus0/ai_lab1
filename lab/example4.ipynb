# %% [markdown]
# # Практическое задание №4

# %%
import shutil

# %%
ls
# Out:
#  Том в устройстве C имеет метку Windows 11
#  Серийный номер тома: 44E9-A893
#
#  Содержимое папки C:\Users\user\ai_lab1\lab
#
# 05/28/2026  10:54 AM    <DIR>          .
# 05/28/2026  05:59 AM    <DIR>          ..
# 05/28/2026  10:53 AM    <DIR>          .ipynb_checkpoints
# 04/16/2026  03:46 AM               281 data.csv
# 05/28/2026  10:53 AM             1,656 example1.ipynb
# 05/28/2026  10:53 AM             1,845 example2.ipynb
# 05/28/2026  10:53 AM             9,625 example3.ipynb
# 05/28/2026  10:53 AM             3,756 example4.ipynb
# 05/28/2026  10:53 AM            14,659 file.ipynb
# 05/28/2026  10:39 AM             2,213 ind1.ipynb
# 05/28/2026  10:47 AM             1,229 magic.ipynb
# 05/28/2026  10:48 AM               937 markdown.ipynb
# 05/28/2026  10:48 AM            40,123 matplotlib.ipynb
# 05/28/2026  10:54 AM               159 test_script.py
#               11 файлов         76,483 байт
#                3 папок  218,638,741,504 байт свободно

# %%
# !where python
# Out:
# C:\Users\user\anaconda3\python.exe
# C:\Users\user\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !mkdir new_folder

# %%
# !rmdir new_folder

# %%
# !mkdir test_folder

# %%
clear
