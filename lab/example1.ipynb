# %%
name = (input("Введите имя:"))
print(f"Привет, {name}! Добро пожаловать в Jupyter Lab!")
# Out:
# Введите имя: Ростислав
# Привет, Ростислав! Добро пожаловать в Jupyter Lab!

# %% [markdown]
# # Практическое задание №1
#
# Добавил "**жирный**" и "*курсивный*" текст
#
# ## Создал нумерованый список:
# 1. Список
# 2. Список
# 3. Список
#
# ## Создал маркированый список:
# - Список
# - Список
# - Список
