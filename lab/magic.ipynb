# %%
# %timeit sum(range(1000))
# Out:
# 8.59 μs ± 288 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%time
total = 0
for i in range(10**8):
    total += i
# Out:
# CPU times: total: 1.77 s
# Wall time: 7.67 s
